# %% [markdown]
# <a href="https://colab.research.google.com/github/marystirling/Convolutional-Neural-Network-Asg-7/blob/main/Lab7_Part1_Ch5_LearningSlowdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/nn/book")    
    
import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
training_data = list(training_data)
    
import network2
net=network2.Network([784,100,10])
net.large_weight_initializer()
net.SGD(training_data, 60, 10, 0.1, lmbda=5.0, evaluation_data=validation_data, monitor_evaluation_accuracy=True)
# Out:
# Epoch 0 training complete in 35.22
# Accuracy on evaluation data: 8973 / 10000
# Epoch 1 training complete in 34.92
# Accuracy on evaluation data: 9223 / 10000
# Epoch 2 training complete in 34.92
# Accuracy on evaluation data: 9306 / 10000
# Epoch 3 training complete in 34.70
# Accuracy on evaluation data: 9368 / 10000
# Epoch 4 training complete in 34.60
# Accuracy on evaluation data: 9423 / 10000
# Epoch 5 training complete in 34.55
# Accuracy on evaluation data: 9465 / 10000
# Epoch 6 training complete in 34.38
# Accuracy on evaluation data: 9516 / 10000
# Epoch 7 training complete in 34.67
# Accuracy on evaluation data: 9542 / 10000
# Epoch 8 training complete in 35.24
# Accuracy on evaluation data: 9580 / 10000
# Epoch 9 training complete in 34.70
# Accuracy on evaluation data: 9574 / 10000
# Epoch 10 training complete in 34.72
# Accuracy on evaluation data: 9596 / 10000
# Epoch 11 training complete in 34.81
# Accuracy on evaluation data: 9608 / 10000
# ...

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/nn/book")

import mnist_loader
training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
training_data = list(training_data)
    
import network2
net=network2.Network([784,100,100,100,10])
net.large_weight_initializer()
net.SGD(training_data, 60, 10, 0.1, lmbda=5.0, evaluation_data=validation_data, monitor_evaluation_accuracy=True)
# Out:
# Epoch 0 training complete in 48.00
# Accuracy on evaluation data: 8885 / 10000
# Epoch 1 training complete in 45.69
# Accuracy on evaluation data: 9100 / 10000
# Epoch 2 training complete in 45.79
# Accuracy on evaluation data: 9308 / 10000
# Epoch 3 training complete in 48.82
# Accuracy on evaluation data: 9397 / 10000
# Epoch 4 training complete in 46.93
# Accuracy on evaluation data: 9469 / 10000
# Epoch 5 training complete in 47.08
# Accuracy on evaluation data: 9499 / 10000
# Epoch 6 training complete in 47.50
# Accuracy on evaluation data: 9542 / 10000
# Epoch 7 training complete in 46.91
# Accuracy on evaluation data: 9555 / 10000
# Epoch 8 training complete in 46.26
# Accuracy on evaluation data: 9566 / 10000
# Epoch 9 training complete in 46.55
# Accuracy on evaluation data: 9560 / 10000
# Epoch 10 training complete in 46.49
# Accuracy on evaluation data: 9602 / 10000
# Epoch 11 training complete in 46.79
# Accuracy on evaluation data: 9583 / 10000
# ...
