# %% [markdown]
# <a href="https://colab.research.google.com/github/marystirling/Convolutional-Neural-Network-Asg-7/blob/main/DownloadCIFAR10LikeData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

for name in class_names:
  os.mkdir(f"/content/drive/MyDrive/Colab Notebooks/cifartest/{name}")

# !pip install icrawler
from icrawler.builtin import GoogleImageCrawler



for name in class_names:
  google_crawler = GoogleImageCrawler(storage={'root_dir': f"/content/drive/MyDrive/Colab Notebooks/cifartest/{name}"})
  google_crawler.crawl(keyword=name, max_num=30)
# Out:
# ...
# 2022-04-14 17:41:24,265 - INFO - downloader - downloader-001 is waiting for new download tasks
# 2022-04-14 17:41:26,437 - INFO - icrawler.crawler - start crawling...
# 2022-04-14 17:41:26,441 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2022-04-14 17:41:26,446 - INFO - feeder - thread feeder-001 exit
# 2022-04-14 17:41:26,448 - INFO - icrawler.crawler - starting 1 parser threads...
# 2022-04-14 17:41:26,455 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2022-04-14 17:41:27,153 - INFO - parser - parsing result page https://www.google.com/search?q=airplane&ijn=0&start=0&tbs=&tbm=isch
# 2022-04-14 17:41:27,392 - INFO - downloader - image #1	https://www.rd.com/wp-content/uploads/2020/01/GettyImages-1131335393-e1580493890249-scaled.jpg
# 2022-04-14 17:41:27,577 - INFO - downloader - image #2	https://m.media-amazon.com/images/M/MV5BZjA3YjdhMWEtYjc2Ni00YzVlLWI0MTUtMGZmNTJjNmU0Yzk2XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_FMjpg_UX1000_.jpg
# ...
